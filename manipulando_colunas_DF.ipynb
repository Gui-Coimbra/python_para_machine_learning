# %% [markdown]
# <a href="https://colab.research.google.com/github/Gui-Coimbra/python_para_machine_learning/blob/main/manipulando_colunas_DF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dados = pd.read_csv('athlete_events.csv')

# %%
dados.rename(columns={'Name':'Nome','Sex':'Sexo','Age':'Idade','Height':'Altura','Weight':'Peso','Team':'Time',
                      'Games':'Jogos','Year':'Ano','Season':'Estacao','City':'Cidade','Sport':'Esporte',
                      'Event':'Modalidade','Medal':'Medalha'}, inplace = True)

# %%
dados.head()
# Out:
#    ID                      Nome Sexo  Idade  Altura  Peso            Time  \
# 0   1                 A Dijiang    M   24.0   180.0  80.0           China
# 1   2                  A Lamusi    M   23.0   170.0  60.0           China
# 2   3       Gunnar Nielsen Aaby    M   24.0     NaN   NaN         Denmark
# 3   4      Edgar Lindenau Aabye    M   34.0     NaN   NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink    F   21.0   185.0  82.0     Netherlands
#
#    NOC        Jogos   Ano Estacao     Cidade        Esporte  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                          Modalidade Medalha
# 0       Basketball Men's Basketball     NaN
# 1      Judo Men's Extra-Lightweight     NaN
# ...

# %%
dados.describe()
# Out:
#                   ID          Idade         Altura           Peso  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                  Ano
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %%
teste = dados

# %%
teste.drop('ID', axis = 1, inplace=True)
teste.drop('Estacao', axis = 1, inplace=True)
teste.drop('Cidade', axis = 1, inplace=True)

# %%
teste.head()
# Out:
#                        Nome Sexo  Idade  Altura  Peso            Time  NOC  \
# 0                 A Dijiang    M   24.0   180.0  80.0           China  CHN
# 1                  A Lamusi    M   23.0   170.0  60.0           China  CHN
# 2       Gunnar Nielsen Aaby    M   24.0     NaN   NaN         Denmark  DEN
# 3      Edgar Lindenau Aabye    M   34.0     NaN   NaN  Denmark/Sweden  DEN
# 4  Christine Jacoba Aaftink    F   21.0   185.0  82.0     Netherlands  NED
#
#          Jogos   Ano     Cidade        Esporte  \
# 0  1992 Summer  1992  Barcelona     Basketball
# 1  2012 Summer  2012     London           Judo
# 2  1920 Summer  1920  Antwerpen       Football
# 3  1900 Summer  1900      Paris     Tug-Of-War
# 4  1988 Winter  1988    Calgary  Speed Skating
#
#                          Modalidade Medalha
# 0       Basketball Men's Basketball     NaN
# 1      Judo Men's Extra-Lightweight     NaN
# 2           Football Men's Football     NaN
# 3       Tug-Of-War Men's Tug-Of-War    Gold
# ...

# %%
masculino = dados.loc[ dados['Sexo'] == 'M' ]
feminino = dados.loc[ dados['Sexo'] == 'F' ]

# %%
masculino.hist(column='Peso', bins=100)
plt.show()

# %%
feminino.hist(column='Peso', bins=100)
plt.show()

# %%
# dados.boxplot(column='Idade')
# Criando com lista, mais de um boxplot
dados.boxplot(column=['Idade','Altura','Peso'])
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %%
plt.scatter(masculino['Altura'], masculino['Peso'])
plt.show()
